# %% [markdown]
# <a href="https://colab.research.google.com/github/manishiitg/ML_Experments/blob/master/nlp/101/word2vec_experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Word2Vec is a very interesting model to learn and gives good understanding into the world of word embeddings.
#
# Below will experiement with word2vec model and some data related to resume data of users.

# %%
import gensim, logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
# !unzip text_cv.zip

# %%
import os 
class MySentences(object):
    def __init__(self, dirname):
        self.dirname = dirname
 
    def __iter__(self):
        for fname in os.listdir(self.dirname):
            for line in open(os.path.join(self.dirname, fname)):
                yield gensim.utils.simple_preprocess(line)
 
sentences = MySentences('text_cv') # a memory-friendly iterator
model = gensim.models.Word2Vec(sentences)
# Out:
# 2019-11-07 12:10:52,257 : INFO : collecting all words and their counts
# 2019-11-07 12:10:52,266 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2019-11-07 12:10:52,338 : INFO : PROGRESS: at sentence #10000, processed 20188 words, keeping 3640 word types
# 2019-11-07 12:10:52,412 : INFO : PROGRESS: at sentence #20000, processed 41072 words, keeping 5888 word types
# 2019-11-07 12:10:52,477 : INFO : PROGRESS: at sentence #30000, processed 61802 words, keeping 7358 word types
# 2019-11-07 12:10:52,543 : INFO : PROGRESS: at sentence #40000, processed 82035 words, keeping 8672 word types
# 2019-11-07 12:10:52,610 : INFO : PROGRESS: at sentence #50000, processed 102623 words, keeping 9972 word types
# 2019-11-07 12:10:52,681 : INFO : PROGRESS: at sentence #60000, processed 123860 words, keeping 11051 word types
# 2019-11-07 12:10:52,745 : INFO : PROGRESS: at sentence #70000, processed 143333 words, keeping 11934 word types
# 2019-11-07 12:10:52,811 : INFO : PROGRESS: at sentence #80000, processed 163773 words, keeping 12774 word types
# 2019-11-07 12:10:52,881 : INFO : PROGRESS: at sentence #90000, processed 185833 words, keeping 13540 word types
# 2019-11-07 12:10:52,951 : INFO : PROGRESS: at sentence #100000, processed 207840 words, keeping 14255 word types
# 2019-11-07 12:10:53,028 : INFO : PROGRESS: at sentence #110000, processed 229179 words, keeping 14987 word types
# 2019-11-07 12:10:53,095 : INFO : PROGRESS: at sentence #120000, processed 249742 words, keeping 15699 word types
# 2019-11-07 12:10:53,162 : INFO : PROGRESS: at sentence #130000, processed 271547 words, keeping 16292 word types
# 2019-11-07 12:10:53,230 : INFO : PROGRESS: at sentence #140000, processed 291709 words, keeping 16863 word types
# 2019-11-07 12:10:53,296 : INFO : PROGRESS: at sentence #150000, processed 312696 words, keeping 17311 word types
# 2019-11-07 12:10:53,375 : INFO : PROGRESS: at sentence #160000, processed 333922 words, keeping 17970 word types
# 2019-11-07 12:10:53,446 : INFO : PROGRESS: at sentence #170000, processed 353809 words, keeping 18453 word types
# 2019-11-07 12:10:53,516 : INFO : PROGRESS: at sentence #180000, processed 374087 words, keeping 19096 word types
# 2019-11-07 12:10:53,582 : INFO : PROGRESS: at sentence #190000, processed 394133 words, keeping 19519 word types
# 2019-11-07 12:10:53,652 : INFO : PROGRESS: at sentence #200000, processed 415054 words, keeping 20082 word types
# 2019-11-07 12:10:53,726 : INFO : PROGRESS: at sentence #210000, processed 435526 words, keeping 20528 word types
# 2019-11-07 12:10:53,796 : INFO : PROGRESS: at sentence #220000, processed 455557 words, keeping 21240 word types
# 2019-11-07 12:10:53,867 : INFO : PROGRESS: at sentence #230000, processed 477259 words, keeping 21741 word types
# 2019-11-07 12:10:53,934 : INFO : PROGRESS: at sentence #240000, processed 496775 words, keeping 22204 word types
# 2019-11-07 12:10:54,004 : INFO : PROGRESS: at sentence #250000, processed 518097 words, keeping 22717 word types
# 2019-11-07 12:10:54,070 : INFO : PROGRESS: at sentence #260000, processed 536802 words, keeping 23208 word types
# 2019-11-07 12:10:54,139 : INFO : PROGRESS: at sentence #270000, processed 555884 words, keeping 23593 word types
# 2019-11-07 12:10:54,216 : INFO : PROGRESS: at sentence #280000, processed 577333 words, keeping 23965 word types
# 2019-11-07 12:10:54,289 : INFO : PROGRESS: at sentence #290000, processed 599282 words, keeping 24517 word types
# 2019-11-07 12:10:54,355 : INFO : PROGRESS: at sentence #300000, processed 619180 words, keeping 24831 word types
# 2019-11-07 12:10:54,435 : INFO : PROGRESS: at sentence #310000, processed 640211 words, keeping 25263 word types
# 2019-11-07 12:10:54,504 : INFO : PROGRESS: at sentence #320000, processed 660178 words, keeping 25589 word types
# 2019-11-07 12:10:54,546 : INFO : collected 25804 word types from a corpus of 673072 raw words and 325680 sentences
# 2019-11-07 12:10:54,548 : INFO : Loading a fresh vocabulary
# 2019-11-07 12:10:54,682 : INFO : effective_min_count=5 retains 7566 unique words (29% of original 25804, drops 18238)
# 2019-11-07 12:10:54,684 : INFO : effective_min_count=5 leaves 641366 word corpus (95% of original 673072, drops 31706)
# 2019-11-07 12:10:54,714 : INFO : deleting the raw counts dictionary of 25804 items
# 2019-11-07 12:10:54,717 : INFO : sample=0.001 downsamples 59 most-common words
# 2019-11-07 12:10:54,718 : INFO : downsampling leaves estimated 544364 word corpus (84.9% of prior 641366)
# 2019-11-07 12:10:54,760 : INFO : estimated required memory for 7566 words and 100 dimensions: 9835800 bytes
# 2019-11-07 12:10:54,762 : INFO : resetting layer weights
# 2019-11-07 12:10:56,192 : INFO : training model with 3 workers on 7566 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2019-11-07 12:10:57,272 : INFO : EPOCH 1 - PROGRESS: at 26.81% examples, 137090 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:10:58,283 : INFO : EPOCH 1 - PROGRESS: at 56.24% examples, 148360 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:10:59,320 : INFO : EPOCH 1 - PROGRESS: at 83.42% examples, 145594 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:10:59,978 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-07 12:10:59,992 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-07 12:10:59,994 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-07 12:10:59,995 : INFO : EPOCH - 1 : training on 673072 raw words (544256 effective words) took 3.8s, 143807 effective words/s
# 2019-11-07 12:11:01,020 : INFO : EPOCH 2 - PROGRESS: at 28.12% examples, 151399 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:02,049 : INFO : EPOCH 2 - PROGRESS: at 59.26% examples, 158465 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:03,072 : INFO : EPOCH 2 - PROGRESS: at 90.56% examples, 160918 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:03,351 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-07 12:11:03,352 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-07 12:11:03,361 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-07 12:11:03,362 : INFO : EPOCH - 2 : training on 673072 raw words (544566 effective words) took 3.4s, 162170 effective words/s
# 2019-11-07 12:11:04,390 : INFO : EPOCH 3 - PROGRESS: at 28.12% examples, 150004 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:05,422 : INFO : EPOCH 3 - PROGRESS: at 57.70% examples, 153493 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:06,442 : INFO : EPOCH 3 - PROGRESS: at 86.32% examples, 152511 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:06,875 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-07 12:11:06,884 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-07 12:11:06,886 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-07 12:11:06,887 : INFO : EPOCH - 3 : training on 673072 raw words (544509 effective words) took 3.5s, 154619 effective words/s
# 2019-11-07 12:11:07,915 : INFO : EPOCH 4 - PROGRESS: at 29.55% examples, 157605 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:08,948 : INFO : EPOCH 4 - PROGRESS: at 60.69% examples, 161160 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:09,987 : INFO : EPOCH 4 - PROGRESS: at 92.19% examples, 161782 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:10,344 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-07 12:11:10,346 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-07 12:11:10,357 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-07 12:11:10,359 : INFO : EPOCH - 4 : training on 673072 raw words (544230 effective words) took 3.5s, 156855 effective words/s
# 2019-11-07 12:11:11,426 : INFO : EPOCH 5 - PROGRESS: at 30.98% examples, 159850 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:12,535 : INFO : EPOCH 5 - PROGRESS: at 62.09% examples, 156578 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:13,640 : INFO : EPOCH 5 - PROGRESS: at 92.19% examples, 153024 words/s, in_qsize 0, out_qsize 0
# 2019-11-07 12:11:13,891 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-07 12:11:13,899 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-07 12:11:13,900 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-07 12:11:13,903 : INFO : EPOCH - 5 : training on 673072 raw words (544366 effective words) took 3.5s, 153812 effective words/s
# 2019-11-07 12:11:13,904 : INFO : training on a 3365360 raw words (2721927 effective words) took 17.7s, 153691 effective words/s

# %%
print(model)

# print(model.wv.vocab)

# model.wv.most_similar(positive=["PHP"])

print(model.wv.vocab.keys())

print(model.wv.most_similar(positive=['excel'], topn=1))

print(model.wv.most_similar(positive=['php']))

print(model.wv.most_similar(positive=['delhi']))

print(model.wv.most_similar(positive=['seo']))

print(model.wv.most_similar(positive=['developer']))

print(model.wv.most_similar(positive=['javascript']))

print(model.wv.most_similar(positive=['reactjs']))
# Out:
# Word2Vec(vocab=7566, size=100, alpha=0.025)
# dict_keys(['akash', 'verma', 'about', 'me', 'february', 'delhi', 'gmail', 'com', 'software', 'development', 'professional', 'to', 'secure', 'position', 'where', 'can', 'efficiently', 'contribute', 'my', 'skill', 'and', 'abilities', 'the', 'growth', 'of', 'organization', 'build', 'carrier', 'in', 'field', 'research', 'education', 'bachelor', 'technology', 'tech', 'cs', 'babu', 'banarasi', 'das', 'engineering', 'college', 'dr', 'abdul', 'kalam', 'technical', 'university', 'lucknow', 'uttar', 'pradesh', 'graduated', 'july', 'marks', 'division', 'hons', 'inter', 'kendriya', 'vidyalaya', 'barabanki', 'cbse', 'board', 'new', 'highschool', 'cgpa', 'skills', 'programming', 'languages', 'data', 'structure', 'using', 'language', 'object', 'oriented', 'core', 'java', 'collection', 'framework', 'jdbc', 'database', 'connectivity', 'script', 'node', 'js', 'sql', 'other', 'html', 'ajax', 'json', 'creating', 'rest', 'api', 'express', 'working', 'with', 'aws', 'bucket', 'dynamodb', 'extracurricular', 'activities', 'participated', 'utkarsh', 'bbd', 'group', 'several', 'events', 'area', 'interest', 'operating', 'system', 'base', 'management', 'seminars', 'seminar', 'on', 'topic', 'search', 'engine', 'optimization', 'techniques', 'at', 'workshop', 'training', 'summer', 'from', 'pie', 'infocomm', 'pvt', 'ltd', 'python', 'softpro', 'india', 'bluetooth', 'ssr', 'automation', 'embedronics', 'design', 'hobbies', 'playing', 'games', 'pc', 'internet', 'surfing', 'personal', 'details', 'father', 'name', 'mr', 'bal', 'krishna', 'date', 'birth', 'gender', 'male', 'marital', 'status', 'single', 'nationality', 'indian', 'declaration', 'hereby', 'declare', 'that', 'information', 'contained', 'here', 'is', 'true', 'correct', 'best', 'knowledge', 'belief', 'rameshwar', 'singh', 'nit', 'bhopal', 'email', 'mobile', 'mentally', 'challenging', 'highly', 'stimulating', 'job', 'this', 'provides', 'an', 'exposure', 'enhance', 'analytical', 'summary', 'materials', 'maulana', 'azad', 'national', 'institute', 'mp', 'mechanical', 'raj', 'kumar', 'goel', 'ghaziabad', 'up', 'proficient', 'php', 'mysql', 'laravel', 'very', 'good', 'mathematics', 'times', 'gate', 'qualified', 'consecutively', 'since', 'qualification', 'no', 'course', 'institution', 'age', 'year', 'manit', 'engg', 'th', 'semester', 'cpi', 'specialization', 'thesis', 'metal', 'matrix', 'lm', 'note', 'till', 'scale', 'project', 'mail', 'title', 'backend', 'developer', 'duration', 'apr', 'team', 'size', 'role', 'description', 'application', 'access', 'emails', 'different', 'servers', 'like', 'hotmail', 'yahoo', 'etc', 'through', 'platform', 'collects', 'user', 'specifically', 'provide', 'includes', 'identify', 'you', 'as', 'specific', 'individual', 'such', 'phone', 'number', 'address', 'your', 'all', 'pages', 'request', 'we', 'what', 'required', 'order', 'requested', 'product', 'or', 'service', 'achievements', 'rank', 'every', 'active', 'participation', 'organized', 'cultural', 'school', 'extra', 'curriculum', 'cricket', 'reading', 'books', 'sex', 'june', 'english', 'hindi', 'permanent', 'gc', 'gaur', 'city', 'gr', 'noida', 'above', 'any', 'if', 'found', 'be', 'false', 'only', 'due', 'place', 'id', 'co', 'objective', 'seek', 'marketing', 'expert', 'optimizer', 'will', 'enhanced', 'used', 'their', 'full', 'potential', 'experience', 'successfully', 'handling', 'organic', 'seo', 'social', 'media', 'understanding', 'google', 'analytics', 'webmaster', 'tools', 'expertise', 'various', 'analyzed', 'customer', 'web', 'sites', 'provided', 'well', 'defined', 'focused', 'strategies', 'for', 'improvement', 'ability', 'grasp', 'technologies', 'quickly', 'apply', 'them', 'jobs', 'work', 'years', 'worked', 'executive', 'digital', 'branch', 'ids', 'logic', 'may', 'nov', 'sr', 'services', 'green', 'park', 'currently', 'gurgaon', 'haryana', 'responsibility', 'page', 'optimizations', 'current', 'company', 'below', 'website', 'analysis', 'competitor', 'keyword', 'meta', 'tags', 'heading', 'alt', 'creation', 'implementation', 'onsite ...
# [('word', 0.8789867162704468)]
# [('java', 0.8427619934082031), ('codeigniter', 0.7804904580116272), ('laravel', 0.7745870351791382), ('wordpress', 0.7691878080368042), ('framework', 0.7536131739616394), ('frontend', 0.7346717119216919), ('mvc', 0.7301052212715149), ('zend', 0.7282220721244812), ('python', 0.7203910946846008), ('codelgniter', 0.7045043706893921)]
# [('kot', 0.7421993017196655), ('heights', 0.7130159139633179), ('ashok', 0.7057321071624756), ('pune', 0.6845118403434753), ('slowdance', 0.6716166138648987), ('faridabad', 0.670676052570343), ('dehradun', 0.6567726135253906), ('gurugram', 0.6535588502883911), ('bangalore', 0.6493149399757385), ('mumbai', 0.6460934281349182)]
# [('smo', 0.8999098539352417), ('ppc', 0.8355027437210083), ('smm', 0.7788927555084229), ('devising', 0.7414702773094177), ('marketing', 0.739463210105896), ('engine', 0.7392500638961792), ('writer', 0.7294918298721313), ('optimizer', 0.7269639372825623), ('campaigns', 0.7181330919265747), ('executive', 0.7109899520874023)]
# [('designer', 0.8623456954956055), ('programmer', 0.8035475015640259), ('devloper', 0.7567287683486938), ('engineer', 0.7472120523452759), ('trainee', 0.7371872663497925), ('intern', 0.7124660015106201), ('webperia', 0.6892287731170654), ('tester', 0.68126380443573), ('technologies', 0.6598612666130066), ('associate', 0.6483489274978638)]
# [('bootstrap', 0.9619841575622559), ('jquery', 0.9406885504722595), ('ajax', 0.8859843611717224), ('angularjs', 0.8856762647628784), ('typescript', 0.8670839071273804), ('reactjs', 0.8651718497276306), ('html', 0.8617407083511353), ('css', 0.8586098551750183), ('es', 0.8533967733383179), ('json', 0.8493567705154419)]
# [('nodejs', 0.95924311876297), ('json', 0.950868546962738), ('ajax', 0.9447394013404846), ('redux', 0.9432094693183899), ('typescript', 0.9372730255126953), ('angularjs', 0.9314691424369812), ('jquery', 0.9226654767990112), ('webservices', 0.9216843247413635), ('frameworks', 0.9206622838973999), ('es', 0.9159210920333862)]
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# **very interesting results and accurate. able to give meaning to words and find similar words quite accurately.**

# %%
print(model.wv.most_similar(positive=['php'],negative=['react']))

print(model.wv.most_similar(positive=['php'], negative=['developer']))
# Out:
# [('tech', 0.5190122127532959), ('diploma', 0.5048667788505554), ('technical', 0.4876195788383484), ('electronics', 0.4807337522506714), ('mits', 0.45318982005119324), ('science', 0.4400334358215332), ('group', 0.4372301995754242), ('degree', 0.4345707893371582), ('university', 0.42114049196243286), ('lucknow', 0.42054831981658936)]
# [('zend', 0.4449006915092468), ('learnt', 0.43517452478408813), ('commanding', 0.4316225051879883), ('python', 0.4232175350189209), ('databases', 0.41631314158439636), ('java', 0.41460561752319336), ('salesforce', 0.38769155740737915), ('library', 0.38608792424201965), ('slave', 0.3856849670410156), ('database', 0.38499125838279724)]
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
